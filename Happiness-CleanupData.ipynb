# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import requests
import time
import random
import csv
import scipy.stats as st
from scipy.stats import linregress

df = pd.read_excel (r'HappinessData.xlsx')

df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.302574        0.450662
# 1     Afghanistan  2009     4.401778            7.472446        0.552308
# 2     Afghanistan  2010     4.758381            7.579183        0.539075
# 3     Afghanistan  2011     3.831719            7.552006        0.521104
# 4     Afghanistan  2012     3.782938            7.637953        0.520637
# ...           ...   ...          ...                 ...             ...
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
new_dfclean=df.drop(columns=['Positive affect','Negative affect'])
new_dfclean=new_dfclean.dropna()
new_dfclean
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.302574        0.450662
# 1     Afghanistan  2009     4.401778            7.472446        0.552308
# 2     Afghanistan  2010     4.758381            7.579183        0.539075
# 3     Afghanistan  2011     3.831719            7.552006        0.521104
# 4     Afghanistan  2012     3.782938            7.637953        0.520637
# ...           ...   ...          ...                 ...             ...
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
# Creating a new data set for the year 2021
new_df2021=new_dfclean[new_dfclean['year']==2021]
len=new_df2021['Country name'].count()
new_df2021.head(len)
#new_dfclean2021=new_df2021.drop(columns=['Positive affect','Negative affect'])
#new_dfclean2021=new_dfclean2021.dropna()
#new_dfclean2021
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 26          Albania  2021     5.255482            9.562287        0.701883
# 56        Argentina  2021     5.908279            9.955421        0.882305
# 71          Armenia  2021     5.300569            9.500485        0.762044
# 86        Australia  2021     7.111599           10.818342        0.919755
# 100         Austria  2021     7.079641           10.892092        0.862976
# ...             ...   ...          ...                 ...             ...
# 1982  United States  2021     6.959088           11.055173        0.920009
# 1998        Uruguay  2021     6.501700           10.010917        0.913873
# 2013     Uzbekistan  2021     6.185308            8.941695        0.895504
# 2072         Zambia  2021     3.082155            8.087629        0.619071
# 2088       Zimbabwe  2021     3.154578            8.153248        0.685151
#
# ...

# %%
# Removing fields with NA values in the data set
#new_dfclean2021=pd.DataFrame(new_df2021.dropna())
new_df2021.to_csv("FilteredData/Happiness2021.csv", index=False, header=True)
new_df2021
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 26          Albania  2021     5.255482            9.562287        0.701883
# 56        Argentina  2021     5.908279            9.955421        0.882305
# 71          Armenia  2021     5.300569            9.500485        0.762044
# 86        Australia  2021     7.111599           10.818342        0.919755
# 100         Austria  2021     7.079641           10.892092        0.862976
# ...             ...   ...          ...                 ...             ...
# 1982  United States  2021     6.959088           11.055173        0.920009
# 1998        Uruguay  2021     6.501700           10.010917        0.913873
# 2013     Uzbekistan  2021     6.185308            8.941695        0.895504
# 2072         Zambia  2021     3.082155            8.087629        0.619071
# 2088       Zimbabwe  2021     3.154578            8.153248        0.685151
#
# ...

# %%
#Dataset for Australia data for the years participated in the Happiness survey
df_country_aus=new_dfclean[new_dfclean['Country name']=="Australia"]
df_country_aus=df_country_aus.dropna()
df_country_aus.to_csv("FilteredData/AustraliaData.csv", index=False, header=True)

df_country_aus
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 73    Australia  2007     7.285391           10.693600        0.965276
# 74    Australia  2008     7.253757           10.708705        0.946635
# 75    Australia  2010     7.450047           10.712526        0.954520
# 76    Australia  2011     7.405616           10.723029        0.967029
# 77    Australia  2012     7.195586           10.743997        0.944599
# 78    Australia  2013     7.364169           10.752455        0.928205
# 79    Australia  2014     7.288550           10.762845        0.923799
# 80    Australia  2015     7.309061           10.769942        0.951862
# 81    Australia  2016     7.250080           10.781371        0.942334
# 82    Australia  2017     7.257038           10.787225        0.949958
# 83    Australia  2018     7.176993           10.800169        0.940137
# 84    Australia  2019     7.233995           10.805864        0.942774
# ...
